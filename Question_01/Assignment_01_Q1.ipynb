# %% [markdown]
# # Question 1 of Assignment 01
# The three stages of reproducible workflow are** Data Input, Data Processing, and Data Analysis. **
# The following is how I would design a workflow for the following data:
#
# ![Screenshot 2024-02-09 172917.png](data:image/png;base64,...)

# %% [markdown]
# #Data Input
#
# At this stage it's important to decide how to retrieve and save data.
#
# First I'd design the directories as such:
# > female_health_project
# >> data_raw
#
# >> data_clean
#
# >> results
#
# >> src
#
# The above table should be converted into a csv file for readability and stored as follows:
#
# > female_health_project
# >> data_raw
# >>> female_patients.csv
#
# In addition a README.txt file should be in data_raw due to give clarification for data stored and a reminder of the unit of measure for each column (Height in inches, Weight, in pounds, Age in years, Grip strength in kilograms, and Fraility Y for Yes and N for No to show if paitent had certain symptoms.)

# %% [markdown]
# #Data Processing
#
# This would be where we could think about missing values or filter out rows or columns depending on our goal with the data. For the current table, there isn't any missing values nor any specified goals there isn't anything needed to be put through cleaning.
#
# If there is any filter wanted of the data, then the cleaned data and source code should be saved as it follows:
#
# > female_health_project
# >> data_clean
# >>> clean_female_patients.csv
#
# >> src
# >>> clean_female_patients.py
#
# All cleaned data will be saved as CSV files for conveience.
# All CSV files resulting from a src code file should have shared prefix name in order to connect src code files to data cleaning results (or shared names if conveintly only one CSV file resulting from src code).

# %% [markdown]
# #Data Analysis
# Data anlaysis is where we try to understand the cleaned data (or in our case the raw data) through statistical tests and data visualization.
#
# Results data should be saved as TXT files and data visualization as whatever file best displays the data. As per data processing, scripts that produce correspondig results and data visualizations should have shared prefixes or names to make clearer which files are produced by which scripts.
#
# Files should be ordered as follows:
#
# > female_health_project
# >> results
# >>> analysis_t-test.txt
#
# >> src
# >>> analysis.py
